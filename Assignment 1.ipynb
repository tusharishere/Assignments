# %%
1. In the below elements which of them are values or an expression? eg:- values can be
integer or string and expressions will be mathematical operators.
*
&#39;hello&#39;
-87.8
-
/
+
6
Answer

Values:

1.'hello' (string)
2.-87.8 (float)
3.6 (integer)

Expressions:

1.*(multiplication operator)
2.-(subtraction operator)
3./ (division operator)
4.+(addition operator)

2. What is the difference between string and variable?
Answer

The difference between string and variable is that 
a string is a specific type of data representing a 
sequence of characters, while a variable is a container 
or empty space that can store various types of data
,including strings. 

3. Describe three different data types.
Answer

Integers: Integers are whole numbers.exmple- x = 10
flots: flots represents real numbers are written with a decimal point.example- x=10.3
string: strings are sequence of character present in enclosed quotes.example- name="Tushar sinha"

4. What is an expression made up of? What do all expressions do?
Answer-
Expressions are combinations of elements like values and operators 
that are used to perform calculations or operations and produce a result.

5. This assignment statements, like spam = 10. What is the difference between an
expression and a statement?
Answer
In the given example spam = 10 is 
an assignment statement that assigns
the value 10 to the variable spam.

expressions are used to produce a result,
while statements are used to perform actions.

6.After running the following code, what does the variable bacon contain?
bacon = 22
bacon + 1

Answer
22

7. What should the values of the following two terms be?
&#39;spam&#39; + &#39;spamspam&#39;
&#39;spam&#39; * 3

Anwser
The values of the two terms would be:

'spamspamspam'
'spamspamspam'

8.Why is eggs a valid variable name while 100 is invalid?

Anwser
Becouse Variable can starts with letters but can not with a digit.

9.What three functions can be used to get the integer, floating-point number, or string
version of a value?

Answer

int()
float()
string()

10.Why does this expression cause an error? How can you fix it?
&#39;I have eaten &#39; + 99 + &#39; burritos.&#39;

Answer

The given expression 'I have eaten ' + 99 + ' burritos.'
causes an error because it attempts to
add a string ('I have eaten ') with an 
integer (99) without converting the 
integer to a string first.

we can fix this expression by coverting 99 to str(99).
'I have eaten ' + str(99) + ' burritos.'
Now output will be
'I have eaten 99 burritos.'
# Out:
#   Cell In [1], line 78
#     9.What three functions can be used to get the integer, floating-point number, or string
#      ^
# SyntaxError: invalid decimal literal
